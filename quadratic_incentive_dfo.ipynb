# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from numpy import linalg as la
import argparse
import pickle
import sys
sys.path.append("../") 
from utils_quadratic import *
import scipy.linalg  as sla
import random
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rng= list(range(1, 100)) # list of integers from 1 to 99
                           # adjust this boundaries to fit your needs
random.shuffle(rng)

d = 3

A1 = np.random.randn(d, d)
Q1 = np.random.randn(d, d)
Q1 = np.dot(Q1, Q1.T)

A2 = np.random.randn(d, d)
Q2 = np.random.randn(d, d)
Q2 = np.dot(Q2,Q2.T)
eta_init = 0.01
MAXINNER = 2000
u = np.ones(d)
x0 = np.ones(2*d)

game = quadratic(Q1, Q2, A1, A2, eta_init, MAXINNER, u, d)
i=0
eigs=game.get_alpha_L(u)
alpha=min(eigs)
L=max(eigs)
eta_bound=alpha/(2*L**2)

while (game.check_jacobian(u) == False) or (game.eta_bound < 0.005) :
    np.random.seed(rng[i])
    A1 = np.random.randn(d, d)
    Q1 = np.random.randn(d, d)
    Q1 = np.dot(Q1, Q1.T) + 2*np.eye(d)

    A2 = np.random.randn(d, d)
    Q2 = np.random.randn(d, d)
    Q2 = np.dot(Q2,Q2.T) + 2*np.eye(d)
    game = quadratic(Q1, Q2, A1, A2, eta_init, MAXINNER, u, d)
    #print(game.eta_bound)
    i+=1
print(i,rng[i])
# Out:
# 4 34

# %%
eigs=game.get_alpha_L(u)
alpha=min(eigs)
L=max(eigs)
eta_bound=alpha/(2*L**2)
eta_bound
# Out:
# 0.005407048062100799

# %%
game.check_jacobian(u)
# Out:
# True

# %% [markdown]
# ## Checking convergence of gradient descent to Nash equilibrium

# %%
game = quadratic(Q1, Q2, A1, A2, eta_bound, MAXINNER, u, d)

# %%
x1, x2 = game.runGradPlay(x0, u)
nash= game.solve_nash(x0)
nash_0 = nash[0:3]
nash_1 = nash[3:6]

# %%
plt.figure(figsize=(10, 6))

plt.plot([np.linalg.norm(x- nash_0) for x in x1], label='Firm 1 Price')
plt.plot([np.linalg.norm(x - nash_1) for x in x2], label='Firm 2 Price')

plt.title('Error to Nash: $\|x^k-x^*(u)\|$ for fixed u='+str(u) + ', tau = ' + str(game.MAXINNER) )
plt.xlabel('Iteration')
plt.ylabel('$\|x^k-x^*(u)\|$')
plt.yscale('log') 
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Checking convergence of SGD

# %%
MAXINNER = 5000

# %%
game = quadratic(Q1, Q2, A1, A2, eta_bound, MAXINNER, u, d)

# %%
x1, x2 = game.runSGDPlay(x0, u)
nash= game.solve_nash(x0)
nash_0 = nash[0:3]
nash_1 = nash[3:6]

# %%
plt.figure(figsize=(10, 6))

plt.plot([np.linalg.norm(x- nash_0) for x in x1], label='Firm 1 Price')
plt.plot([np.linalg.norm(x - nash_1) for x in x2], label='Firm 2 Price')

plt.title('Error to Nash, SGD: $\|x^k-x^*(u)\|$ for fixed u='+str(u) + ', tau = ' + str(game.MAXINNER) )
plt.xlabel('Iteration')
plt.ylabel('$\|x^k-x^*(u)\|$')
plt.yscale('log') 
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Running DFO

# %%
u_d = np.random.rand(d)
game = quadratic(Q1, Q2, A1, A2, eta_bound, MAXINNER, u_d, d)
nash= game.solve_nash(x0)
x0_d = nash[0:3]
x1_d = nash[3:6]

# %%
game.check_jacobian(u)
# Out:
# True

# %%
delta = 0.07
gamma_init = 5
MAXOUTER = 5000
u_init = 2*np.ones(d)
burn_in = 0
MAXINNER = 1200

num_samples = 5

# %% [markdown]
# ## Test a single run here

# %%
ix = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
ix.game=quadratic(ix.Q1, ix.Q2, ix.A1, ix.A2, ix.eta, ix.MAXINNER, ix.u, ix.d)
x1s,x2s=ix.game.runGradPlay(np.ones(2*d),np.ones(d))
x1s,x2s=ix.game.runSGDPlay(np.ones(2*d),np.ones(d), var=0.0001)
x1d,x2d=ix.game.get_xd_constrained(np.ones(d))

# %%
x1d
# Out:
# [array([-0.10407102, -0.189762  , -0.23110095])]

# %%
err1=[la.norm(x1_-x1d[0])**2 for x1_ in x1s]
plt.plot(err1)
plt.yscale('log')

# %%
incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
loss_history_br, u_history, x_history, play_loss = incent_control.runDFOBR(np.ones(2*d))#, 0.001 )

# %%
plt.plot(loss_history_br)
plt.yscale('log')

# %%
np.random.normal(2,1,d)
# Out:
# array([1.44528794, 0.50718887, 4.42149109])

# %%
incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
loss_history, u_history, x_history, play_loss = incent_control.runDFOSGD(np.ones(2*d), 0.001)
#loss_history_sgd, u_history_sgd = incent_control.runDFOSGD(0.001)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [56], line 2
#       1 incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
# ----> 2 loss_history, u_history, x_history, play_loss = incent_control.runDFOSGD(np.ones(2*d), 0.001)
#
# File ~/Desktop/Berkeley Year 1/Spring 2024/Decision Dependence/decision-dependence/2024ICML/ntbks/../utils_quadratic_modified_2.py:83, in incent.runDFOSGD(self, x_init, var)
#      81 v = sample_from_d_sphere(self.d)
#      82 tilde_u=u_history[-1]+self.delta*v
# ---> 83 history_0, history_1 = self.game.runSGDPlay(x_history[-1],tilde_u, var=var) # Run firm gradient play
#      85 x_history.append(np.hstack((history_0[-1],history_1[-1])))
#      87 grad_dfo = self.getGradDFO(history_0[-1], history_1[-1], u_history[-1],v)# Compute gradient for DFO
#
# File ~/Desktop/Berkeley Year 1/Spring 2024/Decision Dependence/decision-dependence/2024ICML/ntbks/../utils_quadratic_modified_2.py:320, in quadratic.runSGDPlay(self, x0, u, var, eta, MAXINNER)
#     318     noise_2 = np.random.normal(0,var,self.d)
#     319     x1s.append(self.proj(x1s[-1] - eta * self.gradPlayer(x1s[-1],x2s[-1],u, 0) + noise_1))
# --> 320     x2s.append(self.proj(x2s[-1] - eta * self.gradPlayer(x1s[-1],x2s[-1],u, 1) + noise_2))
#     322 x1=np.asarray(x1s)
#     323 x2=np.asarray(x2s)
#
# File ~/Desktop/Berkeley Year 1/Spring 2024/Decision Dependence/decision-dependence/2024ICML/ntbks/../utils_quadratic_modified_2.py:248, in quadratic.proj(self, x)
#     242 def proj(self, x):
#     243     """
#     244     Projects the price x onto the interval [lower, upper].
#     245     :param x: Price.
#     246     :return: Projected price.
#     247     """
# --> 248     return np.clip(x, self.lower, self.upper)
#
# File <__array_function__ internals>:180, in clip(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2154, in clip(a, a_min, a_max, out, **kwargs)
#    2085 @array_function_dispatch(_clip_dispatcher)
#    2086 def clip(a, a_min, a_max, out=None, **kwargs):
#    2087     """
#    2088     Clip (limit) the values in an array.
#    2089
#    (...)
#    2152
#    2153     """
# -> 2154     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:135, in _clip(a, min, max, out, casting, **kwargs)
#     133 if not _clip_dep_is_byte_swapped(a) and not _clip_dep_is_byte_swapped(out):
#     134     using_deprecated_nan = False
# --> 135     if _clip_dep_is_scalar_nan(min):
#     136         min = -float('inf')
#     137         using_deprecated_nan = True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:95, in _clip_dep_is_scalar_nan(a)
#      92 def _clip_dep_is_scalar_nan(a):
#      93     # guarded to protect circular imports
#      94     from numpy.core.fromnumeric import ndim
# ---> 95     if ndim(a) != 0:
#      96         return False
#      97     try:
#
# File <__array_function__ internals>:180, in ndim(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3153, in ndim(a)
#    3121 @array_function_dispatch(_ndim_dispatcher)
#    3122 def ndim(a):
#    3123     """
#    3124     Return the number of dimensions of an array.
#    3125
#    (...)
#    3151
#    3152     """
# -> 3153     try:
#    3154         return a.ndim
#    3155     except AttributeError:
#
# KeyboardInterrupt:

# %%
plt.plot(loss_history)
plt.plot(loss_history_br, color ='green')
plt.yscale('log')

# %% [markdown]
# ## DFO: Multiple trials

# %% [markdown]
# ### Gradient Descent (GD)

# %%
u_inits_dict = {}
loss_history_dict = {}
x_history_dict = {}
u_history_dict = {}
play_loss_dict = {}
means_dict = {}
std_dict = {}

# %%
random.seed(42)
num_trials = 10
x_init = np.ones(2*d)

loss_history_all_us = []
x_history_all_us = []
u_history_all_us = []
play_loss_all_us = []
u_init_list = []

u_init_list = []
for i in range(num_trials):
    u_init = np.random.normal(2,1,d)
    incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    loss_history, u_history, x_history, play_loss = incent_control.runDFO(x_init)
    
    u_init_list.append(u_init)
    loss_history_all_us.append(loss_history)
    u_history_all_us.append(u_history)
    x_history_all_us.append(x_history)
    play_loss_all_us.append(play_loss)

# %%
# Convert list of results to a numpy array for easier analysis
loss_history_all_us = np.array(loss_history_all_us)

# Calculate mean and standard deviation
mean_results = np.mean(loss_history_all_us, axis=0)
std_results = np.std(loss_history_all_us, axis=0)

# %%
u_inits_dict['dfo_gd'] = u_init_list
loss_history_dict['dfo_gd'] = loss_history_all_us
x_history_dict['dfo_gd'] = x_history_all_us
u_history_dict['dfo_gd'] = u_history_all_us
play_loss_dict['dfo_gd'] = play_loss_all_us
means_dict['dfo_gd'] = mean_results
std_dict['dfo_gd'] = std_results

# %% [markdown]
# ### Stochastic Gradient Descent (SGD)

# %%
random.seed(42)
num_trials = 10
var = 0.001
x_init = np.ones(2*d)

loss_history_all_us_sgd = []
x_history_all_us_sgd = []
u_history_all_us_sgd = []
play_loss_all_us_sgd = []
u_init_list_sgd = []

for i in range(num_trials):
    u_init = np.random.normal(2,1,d)
    incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    loss_history_sgd, u_history_sgd, x_history_sgd, play_loss_sgd = incent_control.runDFOSGD(x_init, var)
    
    u_init_list_sgd.append(u_init)
    loss_history_all_us_sgd.append(loss_history_sgd)
    u_history_all_us_sgd.append(u_history_sgd)
    x_history_all_us_sgd.append(x_history_sgd)
    play_loss_all_us_sgd.append(play_loss_sgd)

# %%
# Convert list of results to a numpy array for easier analysis
loss_history_all_us_sgd = np.array(loss_history_all_us_sgd)

# Calculate mean and standard deviation
mean_results_sgd = np.mean(loss_history_all_us_sgd, axis=0)
std_results_sgd = np.std(loss_history_all_us_sgd, axis=0)

# %%
u_inits_dict['dfo_sgd'] = u_init_list_sgd
loss_history_dict['dfo_sgd'] = loss_history_all_us_sgd
x_history_dict['dfo_sgd'] = x_history_all_us_sgd
u_history_dict['dfo_sgd'] = u_history_all_us_sgd
play_loss_dict['dfo_sgd'] = play_loss_all_us_sgd
means_dict['dfo_sgd'] = mean_results_sgd
std_dict['dfo_sgd'] = std_results_sgd

# %% [markdown]
# ### Best Response (BR)

# %%
random.seed(42)
loss_history_all_us_br = []
num_trials = 10
x_init = np.ones(2*d)

loss_history_all_us_br = []
x_history_all_us_br = []
u_history_all_us_br = []
play_loss_all_us_br = []
u_init_list_br = []

for i in range(num_trials):
    u_init = np.random.normal(2,1,d)
    incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    loss_history_br, u_history_br, x_history_br, play_loss_br = incent_control.runDFOBR(x_init)
    
    u_init_list_br.append(u_init)
    loss_history_all_us_br.append(loss_history_br)
    u_history_all_us_br.append(u_history_br)
    x_history_all_us_br.append(x_history_br)
    play_loss_all_us_br.append(play_loss_br)

# %%
x_history_1_br = np.array(x_history_all_us_br)[:,:,:3]
x_history_2_br = np.array(x_history_all_us_br)[:,:,3:]

x_history_1_errs_br = np.linalg.norm(x_history_1_br - x0_d, axis=-1)**2
x_history_2_errs_br = np.linalg.norm(x_history_2_br - x1_d, axis=-1)**2

x_history_1_gd = np.array(x_history_all_us)[:,:,:3]
x_history_2_gd = np.array(x_history_all_us)[:,:,3:]

x_history_1_errs_gd = np.linalg.norm(x_history_1_gd - x0_d, axis=-1)**2
x_history_2_errs_gd = np.linalg.norm(x_history_2_gd - x1_d, axis=-1)**2

x_history_1_sgd = np.array(x_history_all_us_sgd)[:,:,:3]
x_history_2_sgd = np.array(x_history_all_us_sgd)[:,:,3:]

x_history_1_errs_sgd = np.linalg.norm(x_history_1_sgd - x0_d, axis=-1)**2
x_history_2_errs_sgd = np.linalg.norm(x_history_2_sgd - x1_d, axis=-1)**2

# %%
for i, result in enumerate(x_history_2_errs_br):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[0], alpha=0.2, label = 'BR')  # Individual trajectories

    
for i, result in enumerate(x_history_2_errs_gd):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[1], alpha=0.2, label = 'GD')  # Individual trajectories

    
for i, result in enumerate(x_history_2_errs_sgd):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[2], alpha=0.2, label = 'SGD')  # Individual trajectories

    
plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert x_2 - x_{2,ps}\Vert^2$', fontsize=fs)
plt.yscale('log')
plt.tick_params(labelsize=fs-4)

# %%
cols
# Out:
# ['xkcd:turquoise', 'xkcd:tangerine', 'xkcd:light lavender']

# %%
for i, result in enumerate(x_history_1_errs_br):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[0], alpha=0.2, label = 'BR')  # Individual trajectories

    
for i, result in enumerate(x_history_1_errs_gd):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[1], alpha=0.2, label = 'GD')  # Individual trajectories

    
for i, result in enumerate(x_history_1_errs_sgd):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[2], alpha=0.2, label = 'SGD')  # Individual trajectories

    
plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert x_1 - x_{1,ps}\Vert^2$', fontsize=fs)
plt.yscale('log')
plt.tick_params(labelsize=fs-4)

# %%
u_history_all_us_br - u_d
# Out:
# (10, 5001, 3)

# %%
u_errs_br = np.linalg.norm(u_history_all_us_br - u_d, axis=-1)**2
u_errs_gd = np.linalg.norm(u_history_all_us - u_d, axis=-1)**2
u_errs_sgd = np.linalg.norm(u_history_all_us_sgd - u_d, axis=-1)**2

# %%
for i, result in enumerate(u_errs_br):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[0], alpha=0.2, label = 'BR')  # Individual trajectories

    
for i, result in enumerate(u_errs_gd):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[1], alpha=0.2, label = 'GD')  # Individual trajectories

    
for i, result in enumerate(u_errs_sgd):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[2], alpha=0.2, label = 'SGD')  # Individual trajectories

    
plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert u - u_{ps}\Vert^2$', fontsize=fs)
plt.yscale('log')
#plt.legend(loc='upper right', fontsize=fs-7)

plt.tick_params(labelsize=fs-4)

# %%
for i, result in enumerate(x_history_1_norms_br):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, label=r'Player 1', color=cols[0], alpha=0.2)  # Individual trajectories

for i, result in enumerate(x_history_2_norms_br):
    (np.linalg.norm(j) for j in result)
    plt.plot(range(MAXOUTER + burn_in + 1), result, label=r'Player 2', color=cols[1], alpha=0.2)  # Individual trajectories

plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert x\Vert^2$', fontsize=fs)

plt.tick_params(labelsize=fs-4)

# %%
# Convert list of results to a numpy array for easier analysis
loss_history_all_us_br = np.array(loss_history_all_us_br)

# Calculate mean and standard deviation
mean_results_br = np.mean(loss_history_all_us_br, axis=0)
std_results_br = np.std(loss_history_all_us_br, axis=0)

# %%
u_inits_dict['dfo_br'] = u_init_list_br
loss_history_dict['dfo_br'] = loss_history_all_us_br
x_history_dict['dfo_br'] = x_history_all_us_br
u_history_dict['dfo_br'] = u_history_all_us_br
play_loss_dict['dfo_br'] = play_loss_all_us_br
means_dict['dfo_br'] = mean_results_br
std_dict['dfo_br'] = std_results_br

# %%
fs=24
import os
import seaborn as sns
sns.set_style("whitegrid")

cols=['xkcd:turquoise','xkcd:tangerine', 'xkcd:light lavender']
plt.figure(figsize=(10, 6))

# Plotting

plt.fill_between(range(MAXOUTER + burn_in + 1), mean_results_br - std_results_br, mean_results_br + std_results_br, color=cols[0], alpha=0.2, label='BR: avg$\pm 1$stdev')
plt.plot(range(MAXOUTER + burn_in+ 1), mean_results_br, label=r'BR: avg', color=cols[0], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(loss_history_all_us_br):
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[0], alpha=0.2)  # Individual trajectories

plt.fill_between(range(MAXOUTER + burn_in + 1), mean_results - std_results, mean_results + std_results, color=cols[1], alpha=0.2, label='GD: avg$\pm 1$stdev')
plt.plot(range(MAXOUTER + burn_in+ 1), mean_results, label=r'GD: avg', color=cols[1], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(loss_history_all_us):
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[1], alpha=0.2)  # Individual trajectories

plt.fill_between(range(MAXOUTER + burn_in + 1), mean_results_sgd - std_results_sgd, mean_results_sgd + std_results_sgd, color=cols[2], alpha=0.2, label='SGD: avg$\pm 1$stdev')
plt.plot(range(MAXOUTER + burn_in+ 1), mean_results_sgd, label=r'SGD: avg', color=cols[2], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(loss_history_all_us_sgd):
    plt.plot(range(MAXOUTER + burn_in + 1), result, color=cols[2], alpha=0.2)  # Individual trajectories

 
    
#plt.title('DFO Trajectories, $u_0 \sim \mathcal{N}(10, 2)$', fontsize=16)
plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert x - x_{se}\Vert^2 + \Vert u-u_{se}\Vert^2$', fontsize=fs)
plt.yscale('log')
plt.legend(loc='upper right', fontsize=fs-7)
plt.tick_params(labelsize=fs-4)

figpath="./figs/"
if not(os.path.exists(figpath)): os.makedirs(figpath)
for tag in ['png','pdf']:
    plt.savefig(figpath+'dfo.'+tag, transparent=True, bbox_inches='tight',dpi=300 )

# %%
import pickle as pk 
data={
    'game': incent_control.game,
    'u_inits_dict': u_inits_dict,
    'x_history_dict': x_history_dict,
    'loss_history_dict': loss_history_dict,
    'loss_history_all_us': loss_history_all_us,
    'play_loss_dict': play_loss_dict,
    'means_dict': means_dict,
    'std_dict':std_dict
}
pk.dump(data, open("dfo_run.pk",'wb'))

# %% [markdown]
# ## Run this for deterministic GD

# %%
loss_history_all_us = []

# Sample u_init and run DFO for each sample
for _ in range(num_samples):
    u_init = np.random.normal(5,2, d)
    incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    loss_history, u_history = incent_control.runDFO()
    
    loss_history_all_us.append(loss_history)

# Convert list of results to a numpy array for easier analysis
loss_history_all_us = np.array(loss_history_all_us)

# Calculate mean and standard deviation
mean_results = np.mean(loss_history_all_us, axis=0)
std_results = np.std(loss_history_all_us, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 4>()
#       5     u_init = np.random.normal(5,2, d)
#       6     incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
# ----> 7     loss_history, u_history = incent_control.runDFO()
#       9     loss_history_all_us.append(loss_history)
#      11 # Convert list of results to a numpy array for easier analysis
#
# TypeError: runDFO() missing 1 required positional argument: 'x_init'

# %% [markdown]
# ## Run this for SGD

# %%
loss_history_all_us_sgd = []

# Sample u_init and run DFO for each sample
for _ in range(num_samples):
    u_init = np.random.normal(5,2, d)
    incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    loss_history, u_history = incent_control.runDFOSGD(0.001)
    
    loss_history_all_us_sgd.append(loss_history)

# Convert list of results to a numpy array for easier analysis
loss_history_all_us_sgd = np.array(loss_history_all_us_sgd)

# Calculate mean and standard deviation
mean_results_sgd = np.mean(loss_history_all_us_sgd, axis=0)
std_results_sgd = np.std(loss_history_all_us_sgd, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 4>()
#       5     u_init = np.random.normal(5,2, d)
#       6     incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
# ----> 7     loss_history, u_history = incent_control.runDFOSGD(0.001)
#       9     loss_history_all_us_sgd.append(loss_history)
#      11 # Convert list of results to a numpy array for easier analysis
#
# TypeError: runDFOSGD() missing 1 required positional argument: 'var'

# %%
# plt.fill_between(range(MAXOUTER + burn_in), mean_results - std_results, mean_results + std_results, color='gray', alpha=0.2, label='Mean ±1 std. dev.')
# plt.plot(range(MAXOUTER + burn_in), mean_results, label='Mean trajectory')
# for result in loss_history_all_us:
#     plt.plot(range(MAXOUTER + burn_in), result, color='blue', alpha=0.2)  # Individual trajectories

# plt.title('DFO Trajectories, $u_0 \sim \mathcal{N}(10, 2)$')
# plt.xlabel('Epochs')
# plt.ylabel('Loss, $\|x - x_d\|^2 + \|u-u_d\|^2$')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import matplotlib as mpl

# # Setting a light style with gridlines
# plt.style.use('seaborn-whitegrid')

# # Create a color palette
# palette = plt.get_cmap('Set1')

# # Increasing default font size
# mpl.rcParams.update({'font.size': 12, 'font.family': 'sans-serif'})

# # Adjusting figure size
# plt.figure(figsize=(10, 6))

# # Plotting
# plt.fill_between(range(MAXOUTER + burn_in), mean_results - std_results, mean_results + std_results, color='gray', alpha=0.2, label='Mean ±1 std. dev.')
# plt.plot(range(MAXOUTER + burn_in), mean_results, label='Mean trajectory', color='darkorange', linewidth=3) # Enhanced visibility for mean trajectory
# for i, result in enumerate(loss_history_all_us):
#     plt.plot(range(MAXOUTER + burn_in), result, color='blue', alpha=0.2)  # Individual trajectories

# # Adding title and labels
# #plt.title('DFO Trajectories, $u_0 \sim \mathcal{N}(10, 2)$', fontsize=16)
# plt.xlabel('Epochs', fontsize=14)
# plt.ylabel('Loss, $\|x - x_d\|^2 + \|u-u_d\|^2$', fontsize=14)

# # Setting yscale to log
# plt.yscale('log')

# # Adding legend
# plt.legend(loc='upper right')

# # Show plot
# plt.show()
# plt.savefig('dfo_sgd.png')

# %%
import pickle as pk 
data={
    'game': incent_control.game,
    'mean_results_sgd': mean_results_sgd,
    'std_results_sgd': std_results_sgd,
    'loss_history_all_us_sgd': loss_history_all_us_sgd,
    'loss_history_all_us': loss_history_all_us,
    'mean_results': mean_results,
    'std_results': std_results
}
pk.dump(data, open("dfo_run.pk",'wb'))

# %%
import pickle as pk 
data={
    'game': incent_control.game,
    'mean_results_sgd': mean_results_sgd,
    'std_results_sgd': std_results_sgd,
    'loss_history_all_us_sgd': loss_history_all_us_sgd,
    'loss_history_all_us': loss_history_all_us,
    'mean_results': mean_results,
    'std_results': std_results
}
pk.dump(data, open("dfo_run_v1.pk",'wb'))

# %%
fs=24
import os
import seaborn as sns
sns.set_style("whitegrid")

cols=['xkcd:tangerine', 'xkcd:turquoise']
plt.figure(figsize=(10, 6))

# Plotting
plt.fill_between(range(MAXOUTER + burn_in + 1), mean_results_sgd - std_results_sgd, mean_results_sgd + std_results_sgd, color=cols[0], alpha=0.2, label=r'SGD: avg$\pm 1$stdev')
plt.plot(range(MAXOUTER + burn_in + 1), mean_results_sgd, label=r'SGD: avg', color=cols[0], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(loss_history_all_us_sgd):
    plt.plot(range(MAXOUTER + burn_in +1), result, color=cols[0], alpha=0.2)  # Individual trajectories

plt.fill_between(range(MAXOUTER + burn_in +1 ), mean_results - std_results, mean_results + std_results, color=cols[1], alpha=0.2, label='GD: avg$\pm 1$stdev')
plt.plot(range(MAXOUTER + burn_in + 1), mean_results, label=r'GD: avg', color=cols[1], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(loss_history_all_us):
    plt.plot(range(MAXOUTER + burn_in+ 1), result, color=cols[1], alpha=0.2)  # Individual trajectories

#plt.title('DFO Trajectories, $u_0 \sim \mathcal{N}(10, 2)$', fontsize=16)
plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert x - x_{se}\Vert^2 + \Vert u-u_{se}\Vert^2$', fontsize=fs)
plt.yscale('log')
plt.legend(loc='upper right', fontsize=fs-4)
plt.tick_params(labelsize=fs-4)

figpath="./figs/"
if not(os.path.exists(figpath)): os.makedirs(figpath)
for tag in ['png','pdf']:
    plt.savefig(figpath+'dfo.'+tag, transparent=True, bbox_inches='tight',dpi=300 )

# %% [markdown]
# ## RGM

# %%
num_trials = 10
data_history = []
err_history = []

for i in range(num_trials):
    ix = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    u0_1 = np.random.normal(2,1,d)
    u0_2 = np.random.normal(2,1,d)
    u0 = np.hstack((u0_1, u0_2))
#print(u0, np.ones(2*d))
    data=ix.runIncentRGM(u0, np.ones(2*d), tag='GP')
    data_history.append(data)
    err_history.append(data['err'])

# %%
# Convert list of results to a numpy array for easier analysis
err_history = np.array(err_history)

# Calculate mean and standard deviation
mean_err = np.mean(err_history, axis=0)
std_err = np.std(err_history, axis=0)

# %%
num_trials = 10
data_history_sgd = []
err_history_sgd = []

for i in range(num_trials):
    ix = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    u0_1 = np.random.normal(2,1,d)
    u0_2 = np.random.normal(2,1,d)
    u0 = np.hstack((u0_1, u0_2))
#print(u0, np.ones(2*d))
    data=ix.runIncentRGM(u0, np.ones(2*d), tag='SGD')
    data_history_sgd.append(data)
    err_history_sgd.append(data['err'])

# %%
# Convert list of results to a numpy array for easier analysis
err_history_sgd = np.array(err_history_sgd)

# Calculate mean and standard deviation
mean_err_sgd = np.mean(err_history_sgd, axis=0)
std_err_sgd = np.std(err_history_sgd, axis=0)

# %%
len(err_history_sgd)
# Out:
# 10

# %%
fs=24
import os
import seaborn as sns
sns.set_style("whitegrid")

cols=['xkcd:tangerine', 'xkcd:turquoise']
plt.figure(figsize=(10, 6))

# Plotting
plt.fill_between(range(6000 + burn_in + 1), mean_err_sgd - std_err_sgd, mean_err_sgd + std_err_sgd, color=cols[1], alpha=0.2, label='SGD: avg$\pm 1$stdev')
plt.plot(range(6000 + burn_in + 1 ), mean_err_sgd, label=r'SGD: avg', color=cols[0], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(err_history_sgd):
    plt.plot(range(6000 + burn_in +1), result, color=cols[0], alpha=0.2)  # Individual trajectories


plt.fill_between(range(6000 + burn_in + 1), mean_err - std_err, mean_err + std_err, color=cols[1], alpha=0.2, label='GD: avg$\pm 1$stdev')
plt.plot(range(6000 + burn_in + 1 ), mean_err, label=r'GD: avg', color=cols[1], linewidth=3) # Enhanced visibility for mean trajectory
for i, result in enumerate(err_history):
    plt.plot(range(6000 + burn_in +1), result, color=cols[1], alpha=0.2)  # Individual trajectories

plt.xlabel('epochs', fontsize=fs)
plt.ylabel('$\Vert x - x_{se}\Vert^2 + \Vert u-u_{se}\Vert^2$', fontsize=fs)
plt.yscale('log')
plt.legend(loc='upper right', fontsize=fs-4)
plt.tick_params(labelsize=fs-4)

figpath="./figs/"
if not(os.path.exists(figpath)): os.makedirs(figpath)
for tag in ['png','pdf']:
    plt.savefig(figpath+'dfo.'+tag, transparent=True, bbox_inches='tight',dpi=300 )

# %%
plt.plot(data['err'])
plt.yscale('log')

# %% [markdown]
# ### Inner Player SGD: DONT RUN THIS

# %%
delta = 0.25
gamma_init = 100
MAXOUTER = 10000
u_init = 2*np.ones(d)
burn_in = 100
MAXINNER = 1200

num_samples = 10
var_inner = 0.00001

# %%
loss_history_all_us = []

# Sample u_init and run DFO for each sample
for _ in range(num_samples):
    u_init = np.random.normal(5,2, d)
    incent_control = incent(Q1, Q2, A1, A2, x0_d, x1_d, u_d, d, delta,u_init, eta_bound, gamma_init, MAXINNER, MAXOUTER, burn_in)
    loss_history, u_history = incent_control.runDFOSGD(var_inner)
    
    loss_history_all_us.append(loss_history)

# Convert list of results to a numpy array for easier analysis
loss_history_all_us = np.array(loss_history_all_us)

# Calculate mean and standard deviation
mean_results = np.mean(loss_history_all_us, axis=0)
std_results = np.std(loss_history_all_us, axis=0)
# Out:
# [7.5534681  2.04453288 7.06511346]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-234.40918632 -913.9981821  -840.53843671]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 796.32760933 -275.98718011 -227.39256806]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-427.10814776  -20.71614054 -761.5079521 ]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-186.77206714   48.4312092   863.00454703]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [341.37298725 162.58520635 896.36386715]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ -396.79139084  -406.95494278 -1008.89475055]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 268.33666929 -638.80871813  519.45582438]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ -80.44009459  -65.20909153 1039.65045658]
# [ 5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 692.29561571 -716.12947041  192.34961103]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-1101.75301141   -71.05673679  -120.62373321]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-569.82146833 -119.6690606   632.0180049 ]
# [ 5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-909.13880442  437.56650619    3.5849546 ]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-291.6927006  -952.1371084  -252.83945966]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-112.29128496  310.6703337  -778.58598121]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-524.00011282  266.49649464  644.1957014 ]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-302.76337321 -708.18751635 -689.79638629]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 220.47855032 -708.19117475 -380.33613361]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 182.68728608  525.80594621 -671.92459924]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [  70.12123643 -930.92990918 -264.61670033]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 328.2404427  -764.16393485 -111.28226968]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 199.37523336 -778.41132134 -242.41005324]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-662.09093253 -295.00396237  551.72374862]
# [ 5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-966.06907448  -78.69190128 -248.02530689]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-791.64586971 -239.98295417    3.8842482 ]
# [ 5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-264.93246043 -173.97146115 -992.58230017]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [  -1.67329099 -821.63582653 -118.04962676]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-105.67625336  404.30594232 -740.75611513]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-82.95771442  42.89433957 896.44608826]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-530.66395179 -540.56700541  620.16413262]
# [ 5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 672.90836132 -734.54215252 -254.24899993]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-423.51740875  310.73097683 -713.2364277 ]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-6.84085164e+02  1.62386742e-01  5.42585937e+02]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 680.17691629 -171.25305961 -777.97933549]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-423.45166758  -15.93867284 -763.62470939]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 821.26723072 -290.66114241 -100.9122915 ]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-639.42546015  441.76194551  513.88209823]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-721.20317211  443.21461372 -495.96612947]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 403.85971714  752.48030927 -118.97014363]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 805.02327252 -397.41244936  294.30957801]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 606.88785031  779.6005542  -474.01588502]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-793.62523253 -501.42927624 -293.37508475]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-604.52302068   24.24140075 -560.89476876]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [876.18151298   2.71479181 260.17885582]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 978.84541498 -387.33689086 -318.13546476]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 547.85052     386.66563329 -535.97476119]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 327.64502735 -468.4548346  -738.5482797 ]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-578.15236211   -1.49558978  718.01486868]
# [ 5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 660.02011787 -138.17468741 -820.48180285]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 593.13005201 -365.86550982  509.32027786]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [933.00356108 302.5390785  364.82070128]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [1046.41860064  226.04442511  -40.07322563]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 744.01629639  -71.54714104 -522.82432288]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-626.54219805   47.02195973 -625.84797213]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 684.28518994 -605.60357819  139.32610214]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 437.38462966 -740.67331643  556.93387913]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [1019.44020962 -177.05709026   92.80535588]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [161.97484748 884.5822924  595.42588095]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [  39.09061673 1031.37378364 -343.17091902]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 895.73264291 -153.48316399  202.29930691]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-626.69694667  449.02393574  762.5492978 ]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [128.6908251  771.5924996  554.26124475]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ -148.21431164   403.96331615 -1046.46808005]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-219.36945185  567.61374455 -568.56466272]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-197.13408172  738.73697709 -335.08499505]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 762.22125293 -247.04052881  460.30919986]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-219.48590286  984.38567272  431.89395103]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-223.97936755 -939.51531372 -364.74544821]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [781.75969241 410.59457682 207.21662229]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [290.2877082  789.32340377 637.52832205]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 358.01337573 -915.63922841 -574.82967721]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 248.31110434 -806.67455856   -7.85294857]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-214.69954067  652.162041    623.36683947]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 139.19249067 -821.44430107  568.78272022]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 329.17035471 -522.87537333 -887.6573928 ]
# [-5.  5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 772.42780231 -273.16598021  229.43080542]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-410.22143181 -951.42184015 -276.11619115]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-744.01252273   32.41669347 -359.5690359 ]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 74.72998004 256.5044388  857.31757158]
# [-5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [1071.55870504  -74.54518744   63.47595209]
# [-5.  5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-117.41664512  710.90952315  798.57218706]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 275.35970529  343.51412138 -927.58954257]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-450.36520311  128.58779987  865.41770868]
# [ 5. -5. -5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-497.29369081  697.32827809 -474.02981338]
# [ 5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-534.66801032 -369.5640939  -559.07054225]
# [5. 5. 5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [ 270.10586719  312.77712712 -753.74282396]
# [-5. -5.  5.]
# SGD Distance to Nash, Burn-in
# True
# True
# 100
# [-431.55561817  831.23622139  -28.46955575]
# [ 5. -5.  5.]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cn/wpc2vc951hs1wtznx5c_whb5kqkshb/T/ipykernel_42199/1937080780.py", line 7, in <module>
#     loss_history, u_history = incent_control.runDFOSGD(var_inner)
#   File "/Users/ksk/Desktop/Berkeley Year 1/Spring 2024/Decision Dependence/decision-dependence/2024ICML/ntbks/../utils_quadratic.py", line 79, in runDFOSGD
#     history_0, history_1, costs_0, cost_1 = self.game.runSGDPlay(var) # Run firm gradient play
#   File "/Users/ksk/Desktop/Berkeley Year 1/Spring 2024/Decision Dependence/decision-dependence/2024ICML/ntbks/../utils_quadratic.py", line 242, in runSGDPlay
#     x_next1 = self.proj(self.x1 - self.eta * self.gradPlayer(0) + noise_1)
#   File "/Users/ksk/Desktop/Berkeley Year 1/Spring 2024/Decision Dependence/decision-dependence/2024ICML/ntbks/../utils_quadratic.py", line 187, in proj
#     return np.clip(x, self.lower, self.upper)
#   File "<__array_function__ internals>", line 179, in clip
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 2081, in _clip_dispatcher
#     def _clip_dispatcher(a, a_min, a_max, out=None, **kwargs):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/Users/ksk/opt/anaconda3/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
import numpy as np
from scipy.optimize import minimize

def objective_function(vars, Q1, Q2, A1, A2, d):
    x1, x2, u = vars[:d], vars[d:2*d], vars[2*d:3*d]
    return x1.T @ Q1 @ x1 + x1.T @ A1 @ x2 + u.T @ x1 + x2 @ Q2 @ x2 + x1.T @ A2 @ x2 + u.T @ x2 + 0.6500001*np.linalg.norm(u)

def constraint1(vars, Q1, Q2, A1, A2, d):
    x1, x2, u = vars[:d], vars[d:2*d], vars[2*d:3*d]
    return 2 * Q1 @ x1 + A1 @ x2 + u

def constraint2(vars, Q1, Q2, A1, A2, d):
    x1, x2, u = vars[:d], vars[d:2*d], vars[2*d:3*d]
    return 2 * Q2 @ x2 + A2.T@x1 + u

def optimize_system(d, Q1, Q2, A1, A2, vars0, bounds):
    # Define constraints
    con1 = {'type': 'eq', 'fun': constraint1, 'args': (Q1, Q2, A1, A2, d)}
    con2 = {'type': 'eq', 'fun': constraint2, 'args': (Q1, Q2, A1, A2, d)}
    constraints = [con1, con2]

    # Perform the optimization
    result = minimize(objective_function, vars0, args=(Q1, Q2, A1, A2, d), method='SLSQP', bounds=bounds, constraints=constraints)

    # Print the result
    print("Optimal values for x1, x2, and u:", result.x)
    print("Minimum value of the objective function:", result.fun)
    print("Optimization successful:", result.success)
    return result

d = 3
bounds_x1 = (-10, 10)  # Bounds for x1
bounds_x2 = (-10, 10)  # Bounds for x2
bounds_u = (-5, 5)  # Bounds for u

bounds = [bounds_x1] * d + [bounds_x2] * d + [bounds_u] * d

# Initial guesses for x1, x2, and u (d-dimensional vectors)
vars0 = np.random.rand(3 * d) 

# Call the optimization function
result = optimize_system(d, Q1, Q2, A1, A2, vars0, bounds)
# Out:
# Optimal values for x1, x2, and u: [-2.87622600e-07 -5.43607093e-08 -2.32044365e-07 -2.99878280e-07
#   2.30259801e-07 -4.39498722e-07  1.41247507e-06 -8.52369100e-07
#   1.60645663e-06]
# Minimum value of the objective function: 1.496739254381626e-06
# Optimization successful: True

# %%
import pickle
with open('game_instance.pkl', 'wb') as file:
    data_to_save = {
        'Q1': Q1,
        'Q2': Q2,
        'A1': A1,
        'A2': A2,
        'x1_d': x0_d,
        'x2_d': x1_d,
        'u_d': u_d
    }
    pickle.dump(data_to_save, file)
